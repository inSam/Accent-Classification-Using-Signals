# %%
import pandas as pd
import librosa
import os
import numpy as np

# %%
df = pd.read_csv('speakers_all.csv')
df = df[df['file_missing?'] == False].reset_index()
df
# Out:
#       index   age  age_onset                         birthplace    filename  \
# 0        32  27.0        9.0             virginia, south africa  afrikaans1
# 1        33  40.0        5.0             pretoria, south africa  afrikaans2
# 2        34  43.0        4.0  pretoria, transvaal, south africa  afrikaans3
# 3        35  26.0        8.0             pretoria, south africa  afrikaans4
# 4        36  19.0        6.0            cape town, south africa  afrikaans5
# ...     ...   ...        ...                                ...         ...
# 2135   2167  46.0        5.0                     lagos, nigeria     yoruba3
# 2136   2168  46.0       12.0                     lagos, nigeria     yoruba4
# 2137   2169  47.0        2.0                    ibadan, nigeria     yoruba5
# 2138   2170  31.0        1.0                bethel, alaska, usa      yupik1
# 2139   2171  24.0       14.0                 bulawayo, zimbabwe       zulu1
#
# ...

# %%
df.groupby('native_language')['native_language'].count() \
                                                .reset_index(name='count') \
                                                .sort_values(['count'], ascending=True)\
                                                .tail(10)
# Out:
#     native_language  count
# 183         turkish     37
# 36            dutch     47
# 145         russian     48
# 138      portuguese     48
# 93           korean     52
# 50           french     63
# 110        mandarin     65
# 6            arabic    102
# 164         spanish    162
# 39          english    579

# %%
def buildset(country_list, df, path):
    X = []
    y = []
    label = 0
    for country in country_list:
        filenames = df[df['native_language'] == country]['filename']
        for name in filenames:
            data, sr = librosa.load(os.path.join(path, name+'.mp3'))
            X.append(data)
            y.append(label)
        label += 1
    return X, np.array(y)

# %%
X, y = buildset(['dutch', 'russian'], df, 'recordings/recordings')
# Out:
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /Users/Tianyi/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
# ...
